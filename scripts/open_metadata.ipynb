# %%
import pickle
import pandas as pd

# %%
pd.read_pickle('/mnt/ampa02_data01/gabacoll/shared/dshntz/info.pkl')
# Out:
#        ID integer_ID instance_counts              corner  \
# 0    0000          0              23   [1061, 4601, 560]
# 1    0001          1              58  [1325, 3350, 1543]
# 2    0002          2               5   [1356, 517, 1669]
# 3    0003          3               7   [1354, 566, 3633]
# 4    0004          4              27   [1331, 2013, 706]
# ..    ...        ...             ...                 ...
# 316  0316        316               1  [1052, 2502, 2773]
# 317  0317        317               1  [1024, 5751, 1221]
# 318  0318        318               1  [1049, 4166, 1427]
# 319  0319        319               9  [1072, 4143, 3769]
# 320  0320        320               1  [1077, 3514, 2325]
#
#                                                 source ref_channel channel  \
# 0    /mnt/ampa02_data01/tmurakami/240417_whole_4col...           3       1
# 1    /mnt/ampa02_data01/tmurakami/240417_whole_4col...           3       1
# ...
